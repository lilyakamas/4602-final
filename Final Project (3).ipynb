# %% [markdown]
# # INFO 4602 Final Project Data
#
# Casey Paul
#
# Serena Rodriguez
#
# Rachel Silverstein
#
# Dallas Walton
#
# Lily Kamas
#
# ## Import libraries

# %%
import pandas as pd
import numpy as np
import requests, os, re, time
from bs4 import BeautifulSoup
from urllib.parse import quote, unquote
from datetime import datetime
from io import BytesIO

# Spatial libaries
import geopandas as gpd
import geoplot, contextily

# Visual libraries
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import seaborn as sb
import altair as alt

# %% [markdown]
# ## Sales reports
# The Colorado Department of Revenue's [Manrijuana Sales Reports](https://revenue.colorado.gov/data-and-reports/marijuana-data/marijuana-sales-reports) stores Excel files on a Google Drive.
#
# Download all excel files. These are files that contain marijuana sales data from January 2014 to Febraury 2021.

# %% [markdown]
# Second, download all the Excel files.

# %%
excel_files = sorted(os.listdir('./COCannabisSalesReport/'))

excel_dictionary = {}

for file in excel_files:
    try:
        _excel_df = pd.read_excel('./COCannabisSalesReport/' + file)

        # Get the date from inside the data
        _date = _excel_df.iloc[1,0].replace('Sales from ','')
        _formatted_date = str(pd.Period(_date))

        # Save
        excel_dictionary[_formatted_date] = _excel_df
    
    except:
        print(file)

# %% [markdown]
# Confirm we got them all.

# %%
sorted(excel_dictionary.keys())
# Out:
# ['2014-01',
#  '2014-02',
#  '2014-03',
#  '2014-04',
#  '2014-05',
#  '2014-06',
#  '2014-07',
#  '2014-08',
#  '2014-09',
#  '2014-10',
#  '2014-11',
#  '2014-12',
#  '2015-01',
#  '2015-02',
#  '2015-03',
#  '2015-04',
#  '2015-05',
#  '2015-06',
#  '2015-07',
#  '2015-08',
#  '2015-09',
#  '2015-10',
#  '2015-11',
#  '2015-12',
#  '2016-01',
#  '2016-02',
#  '2016-03',
#  '2016-04',
#  '2016-05',
#  '2016-06',
#  '2016-07',
#  '2016-08',
#  '2016-09',
#  '2016-10',
#  '2016-11',
#  '2016-12',
#  '2017-01',
#  '2017-02',
#  '2017-03',
#  '2017-04',
#  '2017-05',
#  '2017-06',
#  '2017-07',
#  '2017-08',
#  '2017-09',
#  '2017-10',
#  '2017-11',
#  '2017-12',
#  '2018-01',
#  '2018-02',
#  '2018-03',
#  '2018-04',
#  '2018-05',
#  '2018-06',
#  '2018-07',
#  '2018-08',
#  '2018-09',
#  '2018-10',
#  '2018-11',
#  '2018-12',
#  '2019-01',
#  '2019-02',
#  '2019-03',
#  '2019-04',
#  '2019-05',
#  '2019-06',
#  '2019-07',
#  '2019-08',
#  '2019-09',
#  '2019-10',
#  '2019-11',
#  '2019-12',
#  '2020-01',
#  '2020-02',
#  '2020-03',
#  '2020-04',
#  '2020-05',
#  '2020-06',
#  '2020-07',
#  '2020-08',
#  '2020-09',
#  '2020-10',
#  '2020-11',
#  '2020-12',
#  '2021-01',
#  '2021-02']

# %% [markdown]
# Define a function to parse the files.

# %%
def clean_excel(_df):
    
    # Drop first 5 rows
    _df = _df.drop(index=range(5)).reset_index(drop=True)
    
    # Drop empty column
    _df = _df.dropna(how='all',axis=1)
    
    # Rename columns
    _df.columns = ['Med County','Med Sales','Rec County','Rec Sales']
    
    # Find row for last medical and recreational sales
    last_med = _df[_df['Med County'].str.contains('Sum of NR Counties').fillna(False)].first_valid_index() - 1
    last_rec = _df[_df['Rec County'].str.contains('Sum of NR Counties').fillna(False)].first_valid_index() - 1

    # Slice to only those values
    med_sales = _df.loc[:last_med,['Med County','Med Sales']]
    rec_sales = _df.loc[:last_rec,['Rec County','Rec Sales']]
    
    # Rename columns
    med_sales.columns = ['County','Sales']
    rec_sales.columns = ['County','Sales']

    # Add type
    med_sales['Type'] = 'Medical'
    rec_sales['Type'] = 'Recreational'
    
    # Concatenate
    combined_df = pd.concat([med_sales,rec_sales],ignore_index=True)
    combined_df = combined_df.replace({'Sales':{'NR':np.nan}})

    return combined_df

# %% [markdown]
# Test one of the dictionary keys

# %%
clean_excel(excel_dictionary['2014-01'])
# Out:
#          County       Sales          Type
# 0         Adams    683098.0       Medical
# 1       Alamosa         NaN       Medical
# 2      Arapahoe   1188232.0       Medical
# 3     Archuleta         NaN       Medical
# 4       Boulder   3417873.0       Medical
# 5       Chaffee     83714.0       Medical
# 6   Clear Creek    143736.0       Medical
# 7      Costilla         NaN       Medical
# 8        Denver  15351083.0       Medical
# 9         Eagle    203060.0       Medical
# 10      El Paso   4923633.0       Medical
# 11      Fremont    134388.0       Medical
# 12     Garfield    396086.0       Medical
# 13       Gilpin     28798.0       Medical
# 14        Grand         NaN       Medical
# 15     Gunnison     36244.0       Medical
# 16    Jefferson   1979386.0       Medical
# 17     La Plata    523193.0       Medical
# 18      Larimer    964948.0       Medical
# 19         Mesa         NaN       Medical
# 20       Moffat         NaN       Medical
# 21    Montezuma    100634.0       Medical
# 22     Montrose         NaN       Medical
# 23        Ouray         NaN       Medical
# 24         Park         NaN       Medical
# 25       Pitkin    194865.0       Medical
# 26       Pueblo    419894.0       Medical
# 27        Routt    239509.0       Medical
# 28   San Miguel    164384.0       Medical
# 29     Sedgwick         NaN       Medical
# 30       Summit    271441.0       Medical
# 31       Teller         NaN       Medical
# 32         Weld    657150.0       Medical
# 33        Adams         NaN  Recreational
# 34  Clear Creek    459640.0  Recreational
# 35       Denver   8482593.0  Recreational
# 36     Garfield         NaN  Recreational
# 37       Gilpin    197379.0  Recreational
# 38     Gunnison         NaN  Recreational
# 39    Jefferson    853675.0  Recreational
# 40         Lake         NaN  Recreational
# 41        Ouray         NaN  Recreational
# 42         Park         NaN  Recreational
# 43       Pueblo         NaN  Recreational
# 44        Routt         NaN  Recreational
# 45   San Miguel    338934.0  Recreational
# 46       Summit   1274208.0  Recreational
# 47         Weld         NaN  Recreational

# %% [markdown]
# Loop through files, parse out relevant data, and concatenate results together.

# %%
cleaned_dict = {}

# Apply the function to each month's spreadsheet
for _month, _df in excel_dictionary.items():
    try:
        cleaned_dict[_month] = clean_excel(_df)
    except:
        print(_month)
        pass

# Combine all the months of data together
sales_df = pd.concat(cleaned_dict.values(),keys=cleaned_dict.keys())

# Cleanup
sales_df = sales_df.reset_index(0).reset_index(drop=True)
sales_df = sales_df.rename(columns={'level_0':'Time'})

sales_df = sales_df.sort_values(['Time','County','Type'])

# Write to disk
sales_df.to_csv('colorado_monthly_cannabis_sales.csv',index=False)

print(sales_df.shape)
sales_df.tail()
# Out:
# 2021-01
# 2021-02
# 2020-11
# 2020-12
# (5538, 4)
#          Time    County      Sales          Type
# 4710  2020-10  Sedgwick  1251442.0  Recreational
# 4671  2020-10    Summit        NaN       Medical
# 4711  2020-10    Summit  2409245.0  Recreational
# 4672  2020-10      Weld   373466.0       Medical
# 4712  2020-10      Weld  2966860.0  Recreational

# %% [markdown]
# ## Crime Reports
#
# https://coloradocrimestats.state.co.us/public/Browse/browsetables.aspx
#
# Read in data from the site above. This is the number of DUI arrests for each county in Colorado.

# %%
crime_df = pd.read_csv("DUI Arrests by Month.csv",skiprows=4).dropna(how='all',axis=1)
crime_df.head()
# Out:
#   Arrest Date Arrest Month Jurisdiction by Geography Number of Arrestees
# 0       Total      January                     Total              14,259
# 1       Total      January              Adams County               2,212
# 2       Total      January            Alamosa County                  27
# 3       Total      January           Arapahoe County                 451
# 4       Total      January          Archuleta County                  20

# %% [markdown]
# Change column names
# - Jursidiction by Geography = County
# - Number of Arrestees = Arrests

# %%
crime_df = crime_df.rename(columns={"Jurisdiction by Geography":"County", "Number of Arrestees":"Arrests"})
crime_df.head()
# Out:
#   Arrest Date Arrest Month            County Arrests
# 0       Total      January             Total  14,259
# 1       Total      January      Adams County   2,212
# 2       Total      January    Alamosa County      27
# 3       Total      January   Arapahoe County     451
# 4       Total      January  Archuleta County      20

# %% [markdown]
# Change Arrests to integers

# %%
crime_df["Arrests"] = pd.to_numeric(crime_df["Arrests"].str.replace(",",""))
crime_df.head()
# Out:
#   Arrest Date Arrest Month            County  Arrests
# 0       Total      January             Total  14259.0
# 1       Total      January      Adams County   2212.0
# 2       Total      January    Alamosa County     27.0
# 3       Total      January   Arapahoe County    451.0
# 4       Total      January  Archuleta County     20.0

# %% [markdown]
# Use a Boolean index to filter the data. The new filtered dataframe will no include any `'Arrest Date'` or `'Jurisdiction by Geography'` rows that contain the word 'Total'.
#
# Create a new column titled `Timestamp` that includes the month and year of the arrests. Combine two columns to do this.

# %%
crime_df = crime_df[crime_df['Arrest Date'] != 'Total']
crime_df = crime_df[crime_df['County'] != 'Total']

# Fill any NaNs with 0
# If there is an NaN, this probably means there were no DUI arrests in that county that month.
crime_df = crime_df.fillna(0)
crime_df = crime_df.reset_index(drop=True)


crime_df["Timestamp"] = crime_df['Arrest Month'] + " "+ crime_df["Arrest Date"]
crime_df.head()
# Out:
#   Arrest Date Arrest Month            County  Arrests     Timestamp
# 0        2014      January      Adams County    350.0  January 2014
# 1        2014      January    Alamosa County      0.0  January 2014
# 2        2014      January   Arapahoe County     72.0  January 2014
# 3        2014      January  Archuleta County      1.0  January 2014
# 4        2014      January       Baca County      2.0  January 2014

# %% [markdown]
# Now that we have a new column with the combined month and year, we can drop the columns we got that data from.

# %%
crime_df = crime_df.drop(columns=['Arrest Date','Arrest Month'])
crime_df.head()
# Out:
#              County  Arrests     Timestamp
# 0      Adams County    350.0  January 2014
# 1    Alamosa County      0.0  January 2014
# 2   Arapahoe County     72.0  January 2014
# 3  Archuleta County      1.0  January 2014
# 4       Baca County      2.0  January 2014

# %%
crime_df['Type'] = "DUI"
crime_df.head()
# Out:
#              County  Arrests     Timestamp Type
# 0      Adams County    350.0  January 2014  DUI
# 1    Alamosa County      0.0  January 2014  DUI
# 2   Arapahoe County     72.0  January 2014  DUI
# 3  Archuleta County      1.0  January 2014  DUI
# 4       Baca County      2.0  January 2014  DUI

# %% [markdown]
# Convert `Timestamp` column to a datetime object.

# %%
# Convert to datetime
crime_df['Timestamp'] = pd.to_datetime(crime_df['Timestamp'])

crime_df.head()
# Out:
#              County  Arrests  Timestamp Type
# 0      Adams County    350.0 2014-01-01  DUI
# 1    Alamosa County      0.0 2014-01-01  DUI
# 2   Arapahoe County     72.0 2014-01-01  DUI
# 3  Archuleta County      1.0 2014-01-01  DUI
# 4       Baca County      2.0 2014-01-01  DUI

# %% [markdown]
# ## Merge datasets.
#
# In order to do this, we need to make sure the columns we are joining on are the same types of data and match one another.
#
# First, convert `Time` to a datetime object.
#
# Next, make sure all counties match (i.e. "Boulder County" vs. "Boulder") To do this, add `" County"` to the county names in `sales_df`.

# %%
sales_df['Time'] = pd.to_datetime(sales_df['Time'])

sales_df['County'] = sales_df['County'] + " County"

sales_df = sales_df.fillna(0)

sales_df.head()
# Out:
#          Time            County      Sales          Type
# 0  2014-01-01      Adams County   683098.0       Medical
# 33 2014-01-01      Adams County        0.0  Recreational
# 1  2014-01-01    Alamosa County        0.0       Medical
# 2  2014-01-01   Arapahoe County  1188232.0       Medical
# 3  2014-01-01  Archuleta County        0.0       Medical

# %% [markdown]
# ## County shapefile
#
# Read in the "co_counties" shapefiles. If we want to do anything with geopandas we will need this file.

# %%
co_counties_gdf = gpd.read_file('co_counties/co_counties.shp')
co_counties_gdf.head()
# Out:
#    co_fips     county  househo_20  pop_2010    shape_st_1     shape_st_2  \
# 0      1.0      ADAMS    154502.0  441603.0  3.064413e+09  392729.110497
# 1      3.0    ALAMOSA      6008.0   15445.0  1.872295e+09  177555.351470
# 2      5.0   ARAPAHOE    225124.0  572003.0  2.084863e+09  335003.471310
# 3      7.0  ARCHULETA      5257.0   12084.0  3.504795e+09  263558.683443
# 4     11.0       BENT      1835.0    6499.0  3.990976e+09  254662.200852
#
#    shape_star  shape_stle                                           geometry
# 0         0.0         0.0  POLYGON ((-103.70574 39.99991, -103.70569 39.9...
# 1         0.0         0.0  POLYGON ((-105.59917 37.75216, -105.51619 37.7...
# 2         0.0         0.0  MULTIPOLYGON (((-103.70653 39.73986, -103.7066...
# 3         0.0         0.0  POLYGON ((-107.12854 37.42287, -107.12881 37.3...
# 4         0.0         0.0  POLYGON ((-102.74208 38.26675, -102.74211 38.2...

# %% [markdown]
# Convert the "county" column in `co_counties_gdf` to title-case ([hint](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.title.html)) and show the head after the change.

# %%
co_counties_gdf['County'] = co_counties_gdf['county'].str.title()
co_counties_gdf['County'] = co_counties_gdf['County'] + " County"
co_counties_gdf.head()
# Out:
#    co_fips     county  househo_20  pop_2010    shape_st_1     shape_st_2  \
# 0      1.0      ADAMS    154502.0  441603.0  3.064413e+09  392729.110497
# 1      3.0    ALAMOSA      6008.0   15445.0  1.872295e+09  177555.351470
# 2      5.0   ARAPAHOE    225124.0  572003.0  2.084863e+09  335003.471310
# 3      7.0  ARCHULETA      5257.0   12084.0  3.504795e+09  263558.683443
# 4     11.0       BENT      1835.0    6499.0  3.990976e+09  254662.200852
#
#    shape_star  shape_stle                                           geometry  \
# 0         0.0         0.0  POLYGON ((-103.70574 39.99991, -103.70569 39.9...
# 1         0.0         0.0  POLYGON ((-105.59917 37.75216, -105.51619 37.7...
# 2         0.0         0.0  MULTIPOLYGON (((-103.70653 39.73986, -103.7066...
# 3         0.0         0.0  POLYGON ((-107.12854 37.42287, -107.12881 37.3...
# 4         0.0         0.0  POLYGON ((-102.74208 38.26675, -102.74211 38.2...
#
#              County
# 0      Adams County
# 1    Alamosa County
# 2   Arapahoe County
# 3  Archuleta County
# 4       Bent County

# %% [markdown]
# ## Sales Visuals

# %% [markdown]
# ### Monthly Medical vs. Recreational sales in Colorado
# Reshape the data with "Time" in the index and "Medical" and "Recreational" as columns and the total number of sales as values. Save the resulting reshape as monthly_sales_pivot. You can do this with a pivot table or a groupby-aggregation. Show the tail of this reshaped DataFrame.

# %%
monthly_sales_pivot = pd.pivot_table(sales_df,
                                      index='Time',
                                      columns='Type',
                                      values='Sales',
                                      aggfunc='sum'
                                )

#monthly_sales_pivot = monthly_sales_pivot.reset_index()

monthly_sales_pivot.tail()
# Out:
# Type           Medical  Recreational
# Time
# 2020-06-01  39628326.0   152754961.0
# 2020-07-01  41985544.0   176676875.0
# 2020-08-01  40904451.0   169071513.0
# 2020-09-01  38685046.0   160055956.0
# 2020-10-01  37491986.0   155963920.0

# %%
f,ax = plt.subplots(figsize=(15,10))

monthly_sales_pivot.plot(ax=ax,
                         title = 'Colorado Medical and Recreational Cannabis Sales by Month',
                         xlabel = 'Year',
                         ylabel = 'Number of Sales'
                        )
# Out:
# <AxesSubplot:title={'center':'Colorado Medical and Recreational Cannabis Sales by Month'}, xlabel='Year', ylabel='Number of Sales'>

# %% [markdown]
# ### Interpretation
# In this visual we are comparing medical and recreational sales of marijuana in the state of Colorado from January 2014 to October 2020. The reason this plot stops in October 2020 is because we could only get sales data up to October 2020. At first glance it is clear that recreational sales have greatly increased over the years while medical sales have stayed somewhat constant with some slight fluctuation each month. If we were to make a prediction about future recreational marijuana sales based off of this plot, it is clear that recreational sales will continue to increase.

# %% [markdown]
# ### Monthly Medical vs. Recreational sales in Boulder County
#
# Filter original sales DataFrame to only that Boulder county's values. Note that not all counties permit medical and/or recreational sales and thus may not be present in the data or they have changed their policies over time creating gaps. Reshape the data to include recreational and medical like we did above. Save the result as `county_monthly_sales_pivot`.

# %%
# Boolean index to only Boulder data
boulder_sales_df = sales_df[sales_df['County'] == 'Boulder County']

# Pivot data to get total medical and recreational sales
county_monthly_sales_pivot = pd.pivot_table(boulder_sales_df,
                                            index='Time',
                                            columns='Type',
                                            values='Sales',
                                            aggfunc='sum'
                                           )
# Inspect
county_monthly_sales_pivot.tail()
# Out:
# Type          Medical  Recreational
# Time
# 2020-06-01  1306408.0    10759641.0
# 2020-07-01  1309949.0    12593191.0
# 2020-08-01  1356988.0    12547631.0
# 2020-09-01  1363396.0    11745758.0
# 2020-10-01  1382416.0    11622740.0

# %%
f,ax = plt.subplots(figsize=(15,10))

county_monthly_sales_pivot.plot(ax=ax,
                         title = 'Boulder County Medical and Recreational Cannabis Sales by Month',
                         xlabel = 'Year',
                         ylabel = 'Number of Sales'
                        )
# Out:
# <AxesSubplot:title={'center':'Boulder County Medical and Recreational Cannabis Sales by Month'}, xlabel='Year', ylabel='Number of Sales'>

# %% [markdown]
# ### Interpretation
# In this visual we are comparing medical and recreational sales of marijuana in Boulder County, Colorado from January 2014 to October 2020. The reason this plot stops in October 2020 is because we could only get sales data up to October 2020. Here we see that medical marijuana sales have actually decreased over time while recreational sales have increased. It seems that medical sales are starting to become more consistent starting in early 2019. This could be because people who bought marijuana for medical reasons could now be buying it recreationally instead.

# %% [markdown]
# ### Normalized Medical vs. Recreational Sales

# %%
normalized_df = monthly_sales_pivot.div(monthly_sales_pivot.loc["2014-01-01"])
normalized_df.head()
# Out:
# Type         Medical  Recreational
# Time
# 2014-01-01  1.000000      1.000000
# 2014-02-01  0.971924      1.025790
# 2014-03-01  1.057913      1.447398
# 2014-04-01  0.999196      1.595706
# 2014-05-01  0.960369      1.630176

# %%
f,ax = plt.subplots(figsize=(14,8))

normalized_df['Medical'].plot(ax=ax,
                          title = 'Normalized Colorado Medical and Recreational Sale Values',
                          xlabel = 'Year',
                          ylabel = 'Frequency',
                          label = 'Medical Sales'
                         )

normalized_df['Recreational'].plot(ax=ax,
                                   label = 'Recreational Sales'
                                  )
ax.legend()

# %% [markdown]
# ### Interpretation
# Here we can see that DUI arrests have stayed fairly constant since 2014 (when the data begins) even though recreational sales of marijuana have greatly increased. Since the legalization of marijuana in 2012, recreational sales have increased, however, medical marijuana sales have stayed the same since then. Because both values have been normalized to start at 1, this allows us to see how medical marijuana sales and recreational marijuana sales have changed rather than if they had started at their original values. By starting at 1, we can see a better visualization of their changes over time by being able to compare them right next to one another.

# %% [markdown]
# # Crime Visuals

# %% [markdown]
# ### Monthly DUI crime in Colorado
# Monthly crime pivot

# %%
crime_df.head()
# Out:
#              County  Arrests  Timestamp Type
# 0      Adams County    350.0 2014-01-01  DUI
# 1    Alamosa County      0.0 2014-01-01  DUI
# 2   Arapahoe County     72.0 2014-01-01  DUI
# 3  Archuleta County      1.0 2014-01-01  DUI
# 4       Baca County      2.0 2014-01-01  DUI

# %%
monthly_crime = crime_df.groupby('Timestamp').agg({"Arrests":"sum"})
monthly_crime.head()
# Out:
#             Arrests
# Timestamp
# 2014-01-01   1937.0
# 2014-02-01   1856.0
# 2014-03-01   2372.0
# 2014-04-01   2140.0
# 2014-05-01   2281.0

# %% [markdown]
# ## Combine `monthly_sales_pivot` and `monthly_crime pivots` to make `combined_df`
# ### Then we can normalize the data and make some plots

# %%
monthly_crime.index
# Out:
# DatetimeIndex(['2014-01-01', '2014-02-01', '2014-03-01', '2014-04-01',
#                '2014-05-01', '2014-06-01', '2014-07-01', '2014-08-01',
#                '2014-09-01', '2014-10-01', '2014-11-01', '2014-12-01',
#                '2015-01-01', '2015-02-01', '2015-03-01', '2015-04-01',
#                '2015-05-01', '2015-06-01', '2015-07-01', '2015-08-01',
#                '2015-09-01', '2015-10-01', '2015-11-01', '2015-12-01',
#                '2016-01-01', '2016-02-01', '2016-03-01', '2016-04-01',
#                '2016-05-01', '2016-06-01', '2016-07-01', '2016-08-01',
#                '2016-09-01', '2016-10-01', '2016-11-01', '2016-12-01',
#                '2017-01-01', '2017-02-01', '2017-03-01', '2017-04-01',
#                '2017-05-01', '2017-06-01', '2017-07-01', '2017-08-01',
#                '2017-09-01', '2017-10-01', '2017-11-01', '2017-12-01',
#                '2018-01-01', '2018-02-01', '2018-03-01', '2018-04-01',
#                '2018-05-01', '2018-06-01', '2018-07-01', '2018-08-01',
#                '2018-09-01', '2018-10-01', '2018-11-01', '2018-12-01',
#                '2019-01-01', '2019-02-01', '2019-03-01', '2019-04-01',
#                '2019-05-01', '2019-06-01', '2019-07-01', '2019-08-01',
#                '2019-09-01', '2019-10-01', '2019-11-01', '2019-12-01',
#                '2020-01-01', '2020-02-01', '2020-03-01', '2020-04-01',
#                '2020-05-01', '2020-06-01', '2020-07-01', '2020-08-01',
#                '2020-09-01', '2020-10-01', '2020-11-01', '2020-12-01',
#                '2021-01-01', '2021-02-01', '2021-03-01', '2021-04-01',
#                '2021-05-01', '2021-06-01', '2021-07-01', '2021-08-01',
#                '2021-09-01', '2021-10-01', '2021-11-01', '2021-12-01'],
#               dtype='datetime64[ns]', name='Timestamp', freq=None)

# %%
monthly_sales_pivot.index
# Out:
# DatetimeIndex(['2014-01-01', '2014-02-01', '2014-03-01', '2014-04-01',
#                '2014-05-01', '2014-06-01', '2014-07-01', '2014-08-01',
#                '2014-09-01', '2014-10-01', '2014-11-01', '2014-12-01',
#                '2015-01-01', '2015-02-01', '2015-03-01', '2015-04-01',
#                '2015-05-01', '2015-06-01', '2015-07-01', '2015-08-01',
#                '2015-09-01', '2015-10-01', '2015-11-01', '2015-12-01',
#                '2016-01-01', '2016-02-01', '2016-03-01', '2016-04-01',
#                '2016-05-01', '2016-06-01', '2016-07-01', '2016-08-01',
#                '2016-09-01', '2016-10-01', '2016-11-01', '2016-12-01',
#                '2017-01-01', '2017-02-01', '2017-03-01', '2017-04-01',
#                '2017-05-01', '2017-06-01', '2017-07-01', '2017-08-01',
#                '2017-09-01', '2017-10-01', '2017-11-01', '2017-12-01',
#                '2018-01-01', '2018-02-01', '2018-03-01', '2018-04-01',
#                '2018-05-01', '2018-06-01', '2018-07-01', '2018-08-01',
#                '2018-09-01', '2018-10-01', '2018-11-01', '2018-12-01',
#                '2019-01-01', '2019-02-01', '2019-03-01', '2019-04-01',
#                '2019-05-01', '2019-06-01', '2019-07-01', '2019-08-01',
#                '2019-09-01', '2019-10-01', '2019-11-01', '2019-12-01',
#                '2020-01-01', '2020-02-01', '2020-03-01', '2020-04-01',
#                '2020-05-01', '2020-06-01', '2020-07-01', '2020-08-01',
#                '2020-09-01', '2020-10-01'],
#               dtype='datetime64[ns]', name='Time', freq=None)

# %%
combined_df = pd.merge(left = monthly_crime,
                        right = monthly_sales_pivot,
                        how = 'inner',
                        left_index = True,
                       right_index = True
                     )


combined_df.head()
# Out:
#             Arrests     Medical  Recreational
# 2014-01-01   1937.0  32105349.0    11606429.0
# 2014-02-01   1856.0  31203950.0    11905758.0
# 2014-03-01   2372.0  33964665.0    16799118.0
# 2014-04-01   2140.0  32079528.0    18520452.0
# 2014-05-01   2281.0  30832970.0    18920521.0

# %%
# Divide all arrest values by the January 2014 arrest values
normalized_df = combined_df.div(combined_df.loc['2014-01-01'])

# %% [markdown]
# Add the type of arrest, which in this case we are only looking at DUI data.

# %%
normalized_df['Type'] = "DUI"

# %% [markdown]
# Inspect the head of `normalized_df` to confirm the January 1, 2014 values are 1.

# %%
normalized_df.head()
# Out:
#              Arrests   Medical  Recreational Type
# 2014-01-01  1.000000  1.000000      1.000000  DUI
# 2014-02-01  0.958183  0.971924      1.025790  DUI
# 2014-03-01  1.224574  1.057913      1.447398  DUI
# 2014-04-01  1.104801  0.999196      1.595706  DUI
# 2014-05-01  1.177594  0.960369      1.630176  DUI

# %% [markdown]
# Using `normalized_df`, make a line plot with the normalized DUI and Recreational values. This way we can see if there was increase or decrease in correlation between the two.

# %%
f,ax = plt.subplots(figsize=(14,8))

normalized_df["Arrests"].plot(ax=ax,
                          title = 'Normalized DUI and Recreational Values',
                          xlabel = 'Year',
                          ylabel = 'Frequency',
                          label = 'Arrests'
                         )

normalized_df['Recreational'].plot(ax=ax,
                                   label = 'Recreational Sales'
                                  )
ax.legend()

# %% [markdown]
# Using `normalized_df`, make a line plot with the normalized DUI and Medical values. This way we can see if there was increase or decrease in correlation between the two.

# %%
f,ax = plt.subplots(figsize=(14,8))

normalized_df["Arrests"].plot(ax=ax,
                          title = 'Normalized DUI and Medical Values',
                          xlabel = 'Year',
                          ylabel = 'Frequency',
                          label = 'Arrests'
                         )

normalized_df['Medical'].plot(ax=ax,
                                   label = 'Medical Sales'
                                  )
ax.legend()

# %%
f,ax = plt.subplots(figsize=(10,6))

ax.scatter(normalized_df['Recreational'],   # x-axis data
           normalized_df['Arrests'], # y-axis data
           label = 'Number of Arrests'
          )

# Label your plot!
ax.set_title('Recreational Sales vs. DUI Arrests')
ax.set_xlabel('Recreational')
ax.set_ylabel('DUI')

# Add a legend
ax.legend()

# %% [markdown]
# ### Interpretation
# The plot shows an overall negative relationship between recreational marijuana sales and the number of DUI arrests. As recreational sales increase, the number of DUI arrests decreases.

# %%
f,ax = plt.subplots(figsize=(10,6))

ax.scatter(normalized_df['Medical'],   # x-axis data
           normalized_df['Arrests'], # y-axis data
           label = 'Number of Arrests'
          )

# Label your plot!
ax.set_title('Medical Sales vs DUI Arrests')
ax.set_xlabel('Medical')
ax.set_ylabel('DUI')

# Add a legend
ax.legend()

# %% [markdown]
# ### Interpretation
# The plot shows an overall slightly negative relationship between medical marijuana sales and the number of DUI arrests. As medical sales increase, the number of DUI arrests decreases as well.

# %% [markdown]
# # Spatial Visualizations
# ## Sales Spacials

# %%
co_counties_gdf.head(2)
# Out:
#    co_fips   county  househo_20  pop_2010    shape_st_1     shape_st_2  \
# 0      1.0    ADAMS    154502.0  441603.0  3.064413e+09  392729.110497
# 1      3.0  ALAMOSA      6008.0   15445.0  1.872295e+09  177555.351470
#
#    shape_star  shape_stle                                           geometry  \
# 0         0.0         0.0  POLYGON ((-103.70574 39.99991, -103.70569 39.9...
# 1         0.0         0.0  POLYGON ((-105.59917 37.75216, -105.51619 37.7...
#
#            County
# 0    Adams County
# 1  Alamosa County

# %%
sales_df.head(2)
# Out:
#          Time        County     Sales          Type
# 0  2014-01-01  Adams County  683098.0       Medical
# 33 2014-01-01  Adams County       0.0  Recreational

# %%
sales_gdf = pd.merge(left = co_counties_gdf,
                     right = sales_df,
                     how = 'left',
                     on = 'County'
                    )
print(sales_gdf.shape)
sales_gdf.head()
# Out:
# (5558, 13)
#    co_fips county  househo_20  pop_2010    shape_st_1     shape_st_2  \
# 0      1.0  ADAMS    154502.0  441603.0  3.064413e+09  392729.110497
# 1      1.0  ADAMS    154502.0  441603.0  3.064413e+09  392729.110497
# 2      1.0  ADAMS    154502.0  441603.0  3.064413e+09  392729.110497
# 3      1.0  ADAMS    154502.0  441603.0  3.064413e+09  392729.110497
# 4      1.0  ADAMS    154502.0  441603.0  3.064413e+09  392729.110497
#
#    shape_star  shape_stle                                           geometry  \
# 0         0.0         0.0  POLYGON ((-103.70574 39.99991, -103.70569 39.9...
# 1         0.0         0.0  POLYGON ((-103.70574 39.99991, -103.70569 39.9...
# 2         0.0         0.0  POLYGON ((-103.70574 39.99991, -103.70569 39.9...
# 3         0.0         0.0  POLYGON ((-103.70574 39.99991, -103.70569 39.9...
# 4         0.0         0.0  POLYGON ((-103.70574 39.99991, -103.70569 39.9...
#
#          County       Time     Sales          Type
# 0  Adams County 2014-01-01  683098.0       Medical
# 1  Adams County 2014-01-01       0.0  Recreational
# 2  Adams County 2014-02-01  454940.0       Medical
# 3  Adams County 2014-02-01       0.0  Recreational
# 4  Adams County 2014-03-01  477275.0       Medical

# %% [markdown]
# Filter the data to "Recreational" sales in December 2014. Visualize the "Sales" as a choropleth. Bonus points for using a basemap. Extra bonus points for using a [lognorm colormap](https://matplotlib.org/3.1.0/gallery/userdemo/colormap_normalizations_lognorm.html).

# %%
# Boolean index just Recreational data from October 2014
oct2014_df = sales_gdf['Time'] == '2014-10-01'
only_rec_df = sales_gdf['Type'] == 'Recreational'

# Pass the Boolean series back into the DataFrame and save as a "new" DataFrame
rec_2014_sales = sales_gdf[oct2014_df & only_rec_df]

rec_2014_sales.head(3)
# Out:
#      co_fips     county  househo_20  pop_2010    shape_st_1     shape_st_2  \
# 19       1.0      ADAMS    154502.0  441603.0  3.064413e+09  392729.110497
# 256      5.0   ARAPAHOE    225124.0  572003.0  2.084863e+09  335003.471310
# 412      7.0  ARCHULETA      5257.0   12084.0  3.504795e+09  263558.683443
#
#      shape_star  shape_stle  \
# 19          0.0         0.0
# 256         0.0         0.0
# 412         0.0         0.0
#
#                                               geometry            County  \
# 19   POLYGON ((-103.70574 39.99991, -103.70569 39.9...      Adams County
# 256  MULTIPOLYGON (((-103.70653 39.73986, -103.7066...   Arapahoe County
# 412  POLYGON ((-107.12854 37.42287, -107.12881 37.3...  Archuleta County
#
#           Time  Sales          Type
# 19  2014-10-01    0.0  Recreational
# 256 2014-10-01    0.0  Recreational
# 412 2014-10-01    0.0  Recreational

# %%
rec_2014_sales = rec_2014_sales.to_crs('EPSG:3857')

f,ax = plt.subplots(figsize=(12,10))

rec_2014_sales.plot(column = 'Sales',
                    legend = True,
                    vmin=0,
                    vmax=2000000,
                    cmap = 'plasma',
                    edgecolor = 'w',
                    lw = .3,
                    alpha = .25,
                    legend_kwds = {'shrink':.5},
                    ax=ax
                   )

co_counties_gdf.to_crs('EPSG:3857').plot(ax=ax,edgecolor='k',facecolor='None')

contextily.add_basemap(ax,source=contextily.providers.OpenStreetMap.Mapnik)

# %% [markdown]
# Filter the data to "Recreational" sales in October 2020. Visualize the "Sales" as a choropleth. Bonus points for using a basemap. Extra bonus points for using a [lognorm colormap](https://matplotlib.org/3.1.0/gallery/userdemo/colormap_normalizations_lognorm.html).

# %%
# Boolean index just Recreational data from October 2020
oct2020_df = sales_gdf['Time'] == '2020-10-01'
only_rec_df = sales_gdf['Type'] == 'Recreational'

# Pass the Boolean series back into the DataFrame and save as a "new" DataFrame
rec_2020_sales = sales_gdf[oct2020_df & only_rec_df]

rec_2020_sales.head(3)
# Out:
#      co_fips     county  househo_20  pop_2010    shape_st_1     shape_st_2  \
# 163      1.0      ADAMS    154502.0  441603.0  3.064413e+09  392729.110497
# 400      5.0   ARAPAHOE    225124.0  572003.0  2.084863e+09  335003.471310
# 531      7.0  ARCHULETA      5257.0   12084.0  3.504795e+09  263558.683443
#
#      shape_star  shape_stle  \
# 163         0.0         0.0
# 400         0.0         0.0
# 531         0.0         0.0
#
#                                               geometry            County  \
# 163  POLYGON ((-103.70574 39.99991, -103.70569 39.9...      Adams County
# 400  MULTIPOLYGON (((-103.70653 39.73986, -103.7066...   Arapahoe County
# 531  POLYGON ((-107.12854 37.42287, -107.12881 37.3...  Archuleta County
#
#           Time       Sales          Type
# 163 2020-10-01  13204959.0  Recreational
# 400 2020-10-01  16450038.0  Recreational
# 531 2020-10-01   1481254.0  Recreational

# %%
rec_2020_sales = rec_2020_sales.to_crs('EPSG:3857')

f,ax = plt.subplots(figsize=(12,10))

rec_2020_sales.plot(column = 'Sales',
                    legend = True,
                    vmin=0,
                    vmax=2000000,
                    cmap = 'plasma',
                    edgecolor = 'w',
                    lw = .3,
                    alpha = .25,
                    legend_kwds = {'shrink':.5},
                    ax=ax
                   )

co_counties_gdf.to_crs('EPSG:3857').plot(ax=ax,edgecolor='k',facecolor='None')

contextily.add_basemap(ax,source=contextily.providers.OpenStreetMap.Mapnik)

# %% [markdown]
# ### Interpretation
# Here we are comparing the recreational marijuana sales from October 2014 to October 2020 at the county level. The first thing to note when comparing these visuals is that by 2020 more counties have been filled in with color, indicating that they have legalized the use of recreational marijuana. Additionally, the counties that allowed recreational marijuana sales in 2014 are the counties that now have a higher number of sales in 2020, which can be seen by the lighter colors in the 2020 map. It is interesting to see the differences in sales in each county because it allows us to see a change over time as well as parts of Colorado that still have not legalized the use of recreational marijuana.

# %% [markdown]
# ## Crime spacials

# %%
crime_df.tail()
# Out:
#                                 County  Arrests  Timestamp Type
# 6331                       Weld County      0.0 2021-12-01  DUI
# 6332                       Yuma County      0.0 2021-12-01  DUI
# 6333                 Broomfield County      0.0 2021-12-01  DUI
# 6334  Colorado Bureau of Investigation      0.0 2021-12-01  DUI
# 6335             Colorado State Patrol      0.0 2021-12-01  DUI

# %%
crime_gdf = pd.merge(left = co_counties_gdf,
                     right = crime_df,
                     how = 'left',
                     on = 'County'
                    )
print(crime_gdf.shape)
crime_gdf.head()
# Out:
# (6144, 13)
#    co_fips county  househo_20  pop_2010    shape_st_1     shape_st_2  \
# 0      1.0  ADAMS    154502.0  441603.0  3.064413e+09  392729.110497
# 1      1.0  ADAMS    154502.0  441603.0  3.064413e+09  392729.110497
# 2      1.0  ADAMS    154502.0  441603.0  3.064413e+09  392729.110497
# 3      1.0  ADAMS    154502.0  441603.0  3.064413e+09  392729.110497
# 4      1.0  ADAMS    154502.0  441603.0  3.064413e+09  392729.110497
#
#    shape_star  shape_stle                                           geometry  \
# 0         0.0         0.0  POLYGON ((-103.70574 39.99991, -103.70569 39.9...
# 1         0.0         0.0  POLYGON ((-103.70574 39.99991, -103.70569 39.9...
# 2         0.0         0.0  POLYGON ((-103.70574 39.99991, -103.70569 39.9...
# 3         0.0         0.0  POLYGON ((-103.70574 39.99991, -103.70569 39.9...
# 4         0.0         0.0  POLYGON ((-103.70574 39.99991, -103.70569 39.9...
#
#          County  Arrests  Timestamp Type
# 0  Adams County    350.0 2014-01-01  DUI
# 1  Adams County    361.0 2014-02-01  DUI
# 2  Adams County    451.0 2014-03-01  DUI
# 3  Adams County    397.0 2014-04-01  DUI
# 4  Adams County    445.0 2014-05-01  DUI

# %%
# Boolean index just DUI data from February 2014
feb2014_df = crime_gdf['Timestamp'] == '2014-02-01'
only_DUI_df = crime_gdf['Type'] == 'DUI'

# Pass the Boolean series back into the DataFrame and save as a "new" DataFrame
DUI_2014_crime = crime_gdf[feb2014_df & only_DUI_df]

DUI_2014_crime.head(3)
# Out:
#      co_fips    county  househo_20  pop_2010    shape_st_1     shape_st_2  \
# 1        1.0     ADAMS    154502.0  441603.0  3.064413e+09  392729.110497
# 97       3.0   ALAMOSA      6008.0   15445.0  1.872295e+09  177555.351470
# 193      5.0  ARAPAHOE    225124.0  572003.0  2.084863e+09  335003.471310
#
#      shape_star  shape_stle  \
# 1           0.0         0.0
# 97          0.0         0.0
# 193         0.0         0.0
#
#                                               geometry           County  \
# 1    POLYGON ((-103.70574 39.99991, -103.70569 39.9...     Adams County
# 97   POLYGON ((-105.59917 37.75216, -105.51619 37.7...   Alamosa County
# 193  MULTIPOLYGON (((-103.70653 39.73986, -103.7066...  Arapahoe County
#
#      Arrests  Timestamp Type
# 1      361.0 2014-02-01  DUI
# 97       0.0 2014-02-01  DUI
# 193     66.0 2014-02-01  DUI

# %%
DUI_2014_crime = DUI_2014_crime.to_crs('EPSG:3857')

f,ax = plt.subplots(figsize=(12,10))

DUI_2014_crime.plot(column = 'Arrests',
                    legend = True,
                    vmin=0,
                    vmax=15,
                    cmap = 'plasma',
                    edgecolor = 'w',
                    lw = .3,
                    alpha = .20,
                    legend_kwds = {'shrink':.5},
                    ax=ax
                   )

co_counties_gdf.to_crs('EPSG:3857').plot(ax=ax,edgecolor='k',facecolor='None')

contextily.add_basemap(ax,source=contextily.providers.OpenStreetMap.Mapnik)

# %%
# Boolean index just DUI data from February 2021
feb2021_df = crime_gdf['Timestamp'] == '2021-02-01'
only_DUI_df = crime_gdf['Type'] == 'DUI'

# Pass the Boolean series back into the DataFrame and save as a "new" DataFrame
DUI_2021_crime = crime_gdf[feb2021_df & only_DUI_df]

DUI_2021_crime.head(3)
# Out:
#      co_fips    county  househo_20  pop_2010    shape_st_1     shape_st_2  \
# 85       1.0     ADAMS    154502.0  441603.0  3.064413e+09  392729.110497
# 181      3.0   ALAMOSA      6008.0   15445.0  1.872295e+09  177555.351470
# 277      5.0  ARAPAHOE    225124.0  572003.0  2.084863e+09  335003.471310
#
#      shape_star  shape_stle  \
# 85          0.0         0.0
# 181         0.0         0.0
# 277         0.0         0.0
#
#                                               geometry           County  \
# 85   POLYGON ((-103.70574 39.99991, -103.70569 39.9...     Adams County
# 181  POLYGON ((-105.59917 37.75216, -105.51619 37.7...   Alamosa County
# 277  MULTIPOLYGON (((-103.70653 39.73986, -103.7066...  Arapahoe County
#
#      Arrests  Timestamp Type
# 85     124.0 2021-02-01  DUI
# 181      1.0 2021-02-01  DUI
# 277     19.0 2021-02-01  DUI

# %%
DUI_2021_crime = DUI_2021_crime.to_crs('EPSG:3857')

f,ax = plt.subplots(figsize=(12,10))

DUI_2021_crime.plot(column = 'Arrests',
                    legend = True,
                    vmin=0,
                    vmax=15,
                    cmap = 'plasma',
                    edgecolor = 'w',
                    lw = .3,
                    alpha = .25,
                    legend_kwds = {'shrink':.5},
                    ax=ax
                   )

co_counties_gdf.to_crs('EPSG:3857').plot(ax=ax,edgecolor='k',facecolor='None')

contextily.add_basemap(ax,source=contextily.providers.OpenStreetMap.Mapnik)

# %% [markdown]
# ### Interpretation
# Here we are comparing the number of DUI arrests from February 2014 to February 2021 at the county level. The first thing to note when comparing these visuals is that by 2021 more counties have turned purple, meaning that there have been less DUI’s since 2014. It is interesting to see the differences in DUIs in each county because it allows us to see a change over time. There is no way of knowing for sure if these DUIs are related to the recreational sales of marijuana, but if they were we would note that there is a negative correlation -- as recreational sales have increased over the years the number of DUIs have decreased.
